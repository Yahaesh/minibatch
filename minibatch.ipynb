# %% [markdown]
# <a href="https://colab.research.google.com/github/Yahaesh/minibatch/blob/main/minibatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate synthetic data
X, _ = make_blobs(n_samples=1000, centers=3, n_features=2, random_state=42)

# Configure and fit MiniBatchKMeans
mbk_means = MiniBatchKMeans(n_clusters=3, batch_size=100, random_state=42)
mbk_means.fit(X)

# Visualize the results
plt.scatter(X[:, 0], X[:, 1], c=mbk_means.labels_, cmap='viridis')
